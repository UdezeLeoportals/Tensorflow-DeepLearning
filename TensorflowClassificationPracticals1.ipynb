# %%
import tensorflow as tf
print(tf.__version__)

import datetime
print(f"Notebook last run (end-to-end): {datetime.datetime.now()}")
# Out:
# 2.15.0
# Notebook last run (end-to-end): 2024-05-10 15:31:05.847754

# %% [markdown]
# # Make_Circles Binary classification example with Tensorflow
#
# 1. Build Keras sequential layers using the relu activation function on the top layers to achieve non-linearity
# 2. Use the sigmoid function on the output layer for binary classification
# 3. Use binary_crossentropy as a loss function for binary classification
# 4. Buid sequential layers, compile with optimizer (Adam or SGD) choosing the right (sensitive) learning rate and fit for some number of epochs.

# %%
from sklearn.datasets import make_circles

# Make 1000 examples
n_samples = 1000

# Create circles
X, y = make_circles(n_samples,
                    noise=0.03,
                    random_state=42)

# %%
# Make dataframe of features and labels
import pandas as pd
circles = pd.DataFrame({"X0":X[:, 0], "X1":X[:, 1], "label":y})
circles.head()
# Out:
#          X0        X1  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0

# %%
# Check out the different labels
circles.label.value_counts()
# Out:
# label
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
# Visualize with a plot
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu);

# %%
# Check the shapes of our features and labels
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
import numpy as np

def plot_decision_boundary(model, X, y):
  """
  Plots the decision boundary created by a model predicting on X.
  This function has been adapted from two phenomenal resources:
   1. CS231n - https://cs231n.github.io/neural-networks-case-study/
   2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
  """
  # Define the axis boundaries of the plot and create a meshgrid
  x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
  y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
  xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))

  # Create X values (we're going to predict on all of these)
  x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html

  # Make predictions using the trained model
  y_pred = model.predict(x_in)

  # Check for multi-class
  if model.output_shape[-1] > 1: # checks the final dimension of the model's output shape, if this is > (greater than) 1, it's multi-class
    print("doing multiclass classification...")
    # We have to reshape our predictions to get them ready for plotting
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
  else:
    print("doing binary classifcation...")
    y_pred = np.round(np.max(y_pred, axis=1)).reshape(xx.shape)

  # Plot decision boundary
  plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
  plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model
model1 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation=tf.keras.activations.relu), # hidden layer 1, 4 neurons, ReLU activation
  tf.keras.layers.Dense(80, activation="relu"), # hidden layer 2, 4 neurons, ReLU activation
  tf.keras.layers.Dense(1, activation=tf.keras.activations.sigmoid) # ouput layer
])

# Compile the model
model1.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), # Adam's default learning rate is 0.001
                metrics=['accuracy'])

# Fit the model
history = model1.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 2ms/step - loss: 0.6917 - accuracy: 0.5160
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.5000
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6753 - accuracy: 0.5000
# Epoch 4/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6644 - accuracy: 0.5980
# Epoch 5/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6443 - accuracy: 0.6010
# Epoch 6/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6126 - accuracy: 0.7550
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5663 - accuracy: 0.9070
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4908 - accuracy: 0.9630
# Epoch 9/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.9850
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3184 - accuracy: 0.9980
# Epoch 11/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2513 - accuracy: 0.9890
# Epoch 12/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9990
# Epoch 13/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9990
# Epoch 14/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 1.0000
# Epoch 15/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0894 - accuracy: 0.9990
# Epoch 16/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 18/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 0.9990
# Epoch 19/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 20/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 21/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 22/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 23/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 24/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 25/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 26/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 27/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 28/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 29/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 30/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9990
# Epoch 35/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 36/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 38/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 39/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 40/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 41/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 42/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 43/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 44/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 45/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 46/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 47/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 48/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 49/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 51/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 53/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 54/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 55/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 58/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 59/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 60/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 61/100
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9970
# Epoch 62/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 63/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 64/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 65/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 66/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 67/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 68/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 69/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 70/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 71/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 72/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 73/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 78/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 80/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0039 - accuracy: 0.9990
# Epoch 84/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 85/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 86/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 87/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 89/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 90/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 91/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 92/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 93/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 94/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 95/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 96/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 97/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 98/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000

# %%
# View the predictions of the model with relu and sigmoid activations
plot_decision_boundary(model1, X, y)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %% [markdown]
# ## Sample split into training and test set

# %%
# Split data into train and test sets
X_train, y_train = X[:800], y[:800] # 80% of the data for the training set
X_test, y_test = X[800:], y[800:] # 20% of the data for the test set

# Check the shapes of the data
X_train.shape, X_test.shape # 800 examples in the training set, 200 examples in the test set
# Out:
# ((800, 2), (200, 2))

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model (same as model_7)
model_8 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation="relu"), # hidden layer 1, using "relu" for activation (same as tf.keras.activations.relu)
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(1, activation="sigmoid") # output layer, using 'sigmoid' for the output
])

# Compile the model
model_8.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), # increase learning rate from 0.001 to 0.01 for faster learning
                metrics=['accuracy'])

# Fit the model
history = model_8.fit(X_train, y_train, epochs=25)
# Out:
# Epoch 1/25
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6831 - accuracy: 0.5800
# Epoch 2/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5999 - accuracy: 0.6888
# Epoch 3/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3538 - accuracy: 0.9237
# Epoch 4/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1190 - accuracy: 0.9837
# Epoch 5/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9962
# Epoch 6/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9900
# Epoch 7/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9950
# Epoch 8/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9837
# Epoch 9/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0443 - accuracy: 0.9875
# Epoch 10/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 0.9712
# Epoch 11/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9887
# Epoch 12/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9975
# Epoch 13/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9962
# Epoch 14/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 15/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9875
# Epoch 16/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 0.9950
# Epoch 17/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9875
# Epoch 18/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9862
# Epoch 19/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0121 - accuracy: 0.9962
# Epoch 20/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0407 - accuracy: 0.9837
# Epoch 21/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9887
# Epoch 22/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9975
# Epoch 23/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 0.9975
# Epoch 24/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 25/25
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000

# %%
# Evaluate our model on the test set
loss, accuracy = model_8.evaluate(X_test, y_test)
print(f"Model loss on the test set: {loss}")
print(f"Model accuracy on the test set: {100*accuracy:.2f}%")
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Model loss on the test set: 0.0018949778750538826
# Model accuracy on the test set: 100.00%

# %%
# Plot the decision boundaries for the training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model_8, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model_8, X=X_test, y=y_test)
plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...
# 313/313 [==============================] - 1s 2ms/step
# doing binary classifcation...

# %%
# Plot the loss curves
pd.DataFrame(history.history).plot()
plt.title("Model_8 training curves")
# Out:
# Text(0.5, 1.0, 'Model_8 training curves')

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix

# Make predictions
y_preds = model_8.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step

# %%
# Create a confusion matrix
confusion_matrix(y_test, tf.round(y_preds))
# Out:
# array([[101,   0],
#        [  0,  99]])

# %%
# Note: The following confusion matrix code is a remix of Scikit-Learn's
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
# and Made with ML's introductory notebook - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
import itertools

figsize = (10, 10)

# Create the confusion matrix
cm = confusion_matrix(y_test, tf.round(y_preds))
cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
n_classes = cm.shape[0]

# Let's prettify it
fig, ax = plt.subplots(figsize=figsize)
# Create a matrix plot
cax = ax.matshow(cm, cmap=plt.cm.Blues) # https://matplotlib.org/3.2.0/api/_as_gen/matplotlib.axes.Axes.matshow.html
fig.colorbar(cax)

# Create classes
classes = False

if classes:
  labels = classes
else:
  labels = np.arange(cm.shape[0])

# Label the axes
ax.set(title="Confusion Matrix",
       xlabel="Predicted label",
       ylabel="True label",
       xticks=np.arange(n_classes),
       yticks=np.arange(n_classes),
       xticklabels=labels,
       yticklabels=labels)

# Set x-axis labels to bottom
ax.xaxis.set_label_position("bottom")
ax.xaxis.tick_bottom()

# Adjust label size
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
ax.title.set_size(20)

# Set threshold for different colors
threshold = (cm.max() + cm.min()) / 2.

# Plot the text on each cell
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
           horizontalalignment="center",
           color="white" if cm[i, j] > threshold else "black",
           size=15)

# %% [markdown]
# # Multi-class classification with the inbuilt Fashion MNIST dataset
# 1. Build sequential layer, using relu activation function in the inner layers and specifying input shape at the top layer
# 2. Use softmax activation function at the output layer specifying the number of classes
# 3. Use SparseCategoricalCrossentropy as the loss function for multi-class classification.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# The data has already been sorted into training and test sets for us
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
# Check the shape of our data
train_data.shape, train_labels.shape, test_data.shape, test_labels.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Plot a single example
import matplotlib.pyplot as plt
plt.imshow(train_data[75]);

# %%
# Check our samples label
train_labels[75]
# Out:
# 4

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# How many classes are there (this'll be our output shape)?
len(class_names)
# Out:
# 10

# %%
# Plot an example image and its label
plt.imshow(train_data[17], cmap=plt.cm.binary) # change the colours to black & white
plt.title(class_names[train_labels[17]]);

# %%
# Plot multiple random images of fashion MNIST
import random
plt.figure(figsize=(7, 7))
for i in range(4):
  ax = plt.subplot(2, 2, i + 1)
  rand_index = random.choice(range(len(train_data)))
  plt.imshow(train_data[rand_index], cmap=plt.cm.binary)
  plt.title(class_names[train_labels[rand_index]])
  plt.axis(False)

# %%
# Check the min and max values of the training data
train_data.min(), train_data.max()
# Out:
# (0, 255)

# %%
# Divide train and test images by the maximum value (normalize it)
train_data = train_data / 255.0
test_data = test_data / 255.0

# Check the min and max values of the training data
train_data.min(), train_data.max()
# Out:
# (0.0, 1.0)

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model
model_12 = tf.keras.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)), # input layer (we had to reshape 28x28 to 784)
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(100, activation="relu"),
  tf.keras.layers.Dense(10, activation="softmax") # output shape is 10, activation is softmax
])

# Compile the model
model_12.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                 optimizer=tf.keras.optimizers.Adam(),
                 metrics=["accuracy"])

# Fit the model (to the normalized data)
norm_history = model_12.fit(train_data,
                            train_labels,
                            epochs=100,
                            validation_data=(test_data, test_labels))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.4895 - accuracy: 0.8249 - val_loss: 0.4108 - val_accuracy: 0.8508
# Epoch 2/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3639 - accuracy: 0.8672 - val_loss: 0.4553 - val_accuracy: 0.8469
# Epoch 3/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3311 - accuracy: 0.8792 - val_loss: 0.3724 - val_accuracy: 0.8642
# Epoch 4/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3078 - accuracy: 0.8868 - val_loss: 0.3664 - val_accuracy: 0.8699
# Epoch 5/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2898 - accuracy: 0.8918 - val_loss: 0.3569 - val_accuracy: 0.8715
# Epoch 6/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2758 - accuracy: 0.8966 - val_loss: 0.3676 - val_accuracy: 0.8624
# Epoch 7/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2659 - accuracy: 0.8997 - val_loss: 0.3661 - val_accuracy: 0.8693
# Epoch 8/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2533 - accuracy: 0.9058 - val_loss: 0.3441 - val_accuracy: 0.8832
# Epoch 9/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2440 - accuracy: 0.9084 - val_loss: 0.3438 - val_accuracy: 0.8827
# Epoch 10/100
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.2365 - accuracy: 0.9110 - val_loss: 0.3536 - val_accuracy: 0.8799
# Epoch 11/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2291 - accuracy: 0.9118 - val_loss: 0.3349 - val_accuracy: 0.8838
# Epoch 12/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2219 - accuracy: 0.9161 - val_loss: 0.3511 - val_accuracy: 0.8816
# Epoch 13/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2142 - accuracy: 0.9192 - val_loss: 0.3465 - val_accuracy: 0.8832
# Epoch 14/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2079 - accuracy: 0.9208 - val_loss: 0.3454 - val_accuracy: 0.8907
# Epoch 15/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2008 - accuracy: 0.9230 - val_loss: 0.3709 - val_accuracy: 0.8821
# Epoch 16/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1950 - accuracy: 0.9259 - val_loss: 0.3842 - val_accuracy: 0.8776
# Epoch 17/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1917 - accuracy: 0.9265 - val_loss: 0.3738 - val_accuracy: 0.8863
# Epoch 18/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1861 - accuracy: 0.9282 - val_loss: 0.3451 - val_accuracy: 0.8921
# Epoch 19/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1805 - accuracy: 0.9307 - val_loss: 0.3745 - val_accuracy: 0.8776
# Epoch 20/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1758 - accuracy: 0.9337 - val_loss: 0.4023 - val_accuracy: 0.8810
# Epoch 21/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1720 - accuracy: 0.9343 - val_loss: 0.3789 - val_accuracy: 0.8882
# Epoch 22/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.
100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0634 - accuracy: 0.9761 - val_loss: 0.8519 - val_accuracy: 0.8820
# Epoch 83/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0651 - accuracy: 0.9756 - val_loss: 0.9020 - val_accuracy: 0.8877
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0655 - accuracy: 0.9762 - val_loss: 0.8525 - val_accuracy: 0.8897
# Epoch 85/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0646 - accuracy: 0.9752 - val_loss: 0.8594 - val_accuracy: 0.8887
# Epoch 86/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0611 - accuracy: 0.9763 - val_loss: 0.9464 - val_accuracy: 0.8832
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0614 - accuracy: 0.9761 - val_loss: 0.8793 - val_accuracy: 0.8896
# Epoch 88/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0620 - accuracy: 0.9763 - val_loss: 0.8174 - val_accuracy: 0.8887
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0615 - accuracy: 0.9776 - val_loss: 0.8991 - val_accuracy: 0.8868
# Epoch 90/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0637 - accuracy: 0.9755 - val_loss: 0.9148 - val_accuracy: 0.8842
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0542 - accuracy: 0.9789 - val_loss: 0.9070 - val_accuracy: 0.8882
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0647 - accuracy: 0.9764 - val_loss: 0.9339 - val_accuracy: 0.8873
# Epoch 93/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0588 - accuracy: 0.9776 - val_loss: 0.9365 - val_accuracy: 0.8847
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0569 - accuracy: 0.9785 - val_loss: 0.8997 - val_accuracy: 0.8868
# Epoch 95/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0582 - accuracy: 0.9785 - val_loss: 0.9087 - val_accuracy: 0.8803
# Epoch 96/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0604 - accuracy: 0.9776 - val_loss: 0.9203 - val_accuracy: 0.8927
# Epoch 97/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0572 - accuracy: 0.9788 - val_loss: 0.9449 - val_accuracy: 0.8893
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0561 - accuracy: 0.9790 - val_loss: 1.0156 - val_accuracy: 0.8882
# Epoch 99/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0583 - accuracy: 0.9792 - val_loss: 0.9682 - val_accuracy: 0.8868
# Epoch 100/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0551 - accuracy: 0.9797 - val_loss: 1.0003 - val_accuracy: 0.8867

# %%
import pandas as pd

# Plot normalized data loss curves
pd.DataFrame(norm_history.history).plot(title="Normalized data");

# %%
# Note: The following confusion matrix code is a remix of Scikit-Learn's
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
# and Made with ML's introductory notebook - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
import itertools
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15):
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).

  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])

  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes),
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)

  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
             horizontalalignment="center",
             color="white" if cm[i, j] > threshold else "black",
             size=text_size)

# %%
# Make predictions with the most recent model
y_probs = model_12.predict(test_data) # "probs" is short for probabilities
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
# Convert all of the predictions from probabilities to labels
y_preds = y_probs.argmax(axis=1)

# View the first 10 prediction labels
y_preds[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7])

# %%
# Check out the non-prettified confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true=test_labels,
                 y_pred=y_preds)
# Out:
# array([[838,   1,  11,  23,   6,   2, 115,   0,   4,   0],
#        [  3, 981,   0,   8,   2,   0,   3,   0,   3,   0],
#        [ 17,   2, 788,  17,  89,   0,  87,   0,   0,   0],
#        [ 15,  15,   8, 906,  27,   0,  26,   0,   3,   0],
#        [  3,   2,  77,  29, 791,   0,  95,   0,   3,   0],
#        [  1,   0,   0,   0,   0, 974,   0,  19,   0,   6],
#        [115,   2,  64,  31,  43,   1, 732,   0,  12,   0],
#        [  0,   0,   0,   0,   0,  10,   0, 985,   0,   5],
#        [  6,   1,   1,   5,   1,   5,  10,   5, 966,   0],
#        [  1,   0,   0,   1,   0,  10,   0,  82,   0, 906]])

# %%
import numpy as np

# %%
# Make a prettier confusion matrix
make_confusion_matrix(y_true=test_labels,
                      y_pred=y_preds,
                      classes=class_names,
                      figsize=(15, 15),
                      text_size=10)

# %%
import random

# Create a function for plotting a random image along with its prediction
def plot_random_image(model, images, true_labels, classes):
  """Picks a random image, plots it and labels it with a predicted and truth label.

  Args:
    model: a trained model (trained on data similar to what's in images).
    images: a set of random images (in tensor form).
    true_labels: array of ground truth labels for images.
    classes: array of class names for images.

  Returns:
    A plot of a random image from `images` with a predicted class label from `model`
    as well as the truth class label from `true_labels`.
  """
  # Setup random integer
  i = random.randint(0, len(images))

  # Create predictions and targets
  target_image = images[i]
  pred_probs = model.predict(target_image.reshape(1, 28, 28)) # have to reshape to get into right size for model
  pred_label = classes[pred_probs.argmax()]
  true_label = classes[true_labels[i]]

  # Plot the target image
  plt.imshow(target_image, cmap=plt.cm.binary)

  # Change the color of the titles depending on if the prediction is right or wrong
  if pred_label == true_label:
    color = "green"
  else:
    color = "red"

  # Add xlabel information (prediction/true label)
  plt.xlabel("Pred: {} {:2.0f}% (True: {})".format(pred_label,
                                                   100*tf.reduce_max(pred_probs),
                                                   true_label),
             color=color) # set the color to green or red

# %%
# Check out a random image as well as its prediction
plot_random_image(model=model_12,
                  images=test_data,
                  true_labels=test_labels,
                  classes=class_names)
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
model_12.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_9 (Dense)             (None, 100)               78500
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dense_11 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

# See the inputs and outputs of each layer
plot_model(model_12, show_shapes=True)
